# %%
import pandas as pd
import os
import numpy as np
from pathlib import Path
import matplotlib.pyplot as plt
import csv
from datetime import datetime
from plotnine import *

# %% [markdown]
# ### Defining paths

# %%
currdir= Path(os.path.join('..', os.getcwd()))
path = str(currdir.parent)

# %% [markdown]
# ### Creating Figures directory

# %%
figpath = os.path.join(path, 'Figures')

def makedirectory():
    
    if not os.path.exists(figpath):
        
        print("path doesnot exist")
        
        figout = os.makedirs(figpath)
        
        print("Figure directory is created")
        
        return figout
    
    else:
        
        print("Directory already existed")
        
        return None
    
figout = makedirectory()
# Out:
# path doesnot exist
# Figure directory is created

# %% [markdown]
# ## Loading Datafiles

# %%
class load_data:
    
    
    def __init__(self,path):
        
        self.path = path
        
        
    def patients_data(self):
        
        lst = [d for d, subdir, files in os.walk(self.path, topdown=True)]

        filepath = [x for x in lst if len(x) == max([len(x) for x in lst])]

        return filepath
    
    
    def dev_files(self):
        
        lst = [d for d, subdir, files in os.walk(self.path, topdown=True)]

        filepath = [x for x in lst if len(x) == max([len(x) for x in lst])]
        
        devpath = []
        
        for f in filepath:
            
            tmp = os.listdir(f)
    
            for t in tmp:
        
                if "dev" in t and t.endswith(".csv"):
            
                    devpath.append(os.path.join(f, t))

        return devpath
    
    
    def summary_files(self):
        
        lst = [d for d, subdir, files in os.walk(self.path, topdown=True)]

        filepath = [x for x in lst if len(x) == max([len(x) for x in lst])]
        
        spath = []
        
        for f in filepath:
            
            tmp = os.listdir(f)
    
            for t in tmp:
        
                if "Summary" in t and t.endswith(".csv"):
            
                    spath.append(os.path.join(f, t))

        return spath
    

## Calling functions
    
        
subclass = load_data(path)   

devpath = subclass.dev_files()

devpath = devpath

patients_data = subclass.patients_data()

spath = subclass.summary_files()


print(patients_data)
print(devpath)
print(spath)
# Out:
# ['/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-014_170614H/170614H-2017-11-21-09-24-34', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/04-003_170657H/170657H-2018-01-24-15-19-59', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-001_170403H/170403H-2017-09-25-08-54-36']
# ['/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-014_170614H/170614H-2017-11-21-09-24-34/dev_2017-11-21_09-24-34-70-77-20751-13110-14136-14384.csv', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/04-003_170657H/170657H-2018-01-24-15-19-59/dev_2018-01-24_15-19-59-55-55-20748-13110-14136-14384.csv', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-001_170403H/170403H-2017-09-25-08-54-36/dev_2017-09-25_08-54-36-56-90-20748-13110-14136-14384.csv']
# ['/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-014_170614H/170614H-2017-11-21-09-24-34/170614H-2017-11-21-09-24-34--Summary.csv', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/04-003_170657H/170657H-2018-01-24-15-19-59/170657H-2018-01-24-15-19-59--Summary.csv', '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-001_170403H/170403H-2017-09-25-08-54-36/170403H-2017-09-25-08-54-36--Summary.csv']

# %%
patients_data
# Out:
# ['/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-014_170614H/170614H-2017-11-21-09-24-34',
#  '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/04-003_170657H/170657H-2018-01-24-15-19-59',
#  '/Users/habbasi/Desktop/Interview_Data Analysis_Test_Set/01-001_170403H/170403H-2017-09-25-08-54-36']

# %%
for p in patients_data:
    
    timestamp=[]
    
    filenames=[]
    
    for f in os.listdir(p):
        
        if f.startswith("cal_") and f.endswith(".csv"):
            
            calpath = os.path.join(p, f)
            
            with open(calpath) as csvfile:

                call_data = list(csv.reader(csvfile))

                # Getting index if it matches with string list 

                t_stamp = call_data[5][0]
                
                timestamp.append(t_stamp)
                
                filenames.append(p)
                           
                
    cal_time = pd.DataFrame(zip(timestamp, filenames), columns=['timestamp', 'filename'])
    
    ## reading dev file in each patient
    
    devpath = [os.path.join(p, d) for d in os.listdir(p) if "dev" in d and d.endswith(".csv")][0]
    
    ## Processing dev files to get timestamps to match get pre-ST and post-ST cal files

    dev = pd.read_csv(devpath)
           
           
    row = (dev.iloc[:, 0] == 'time').idxmax()

    dev.columns = dev.loc[row]

    dev = (dev.loc[row+1:, :]
           
           .reset_index(drop=True)
          )


    data_dype = ['124', '125']

    dev = (dev[dev['type']
               
               .isin(data_dype)]
           
           .sort_values(by=['type'])
           
           .reset_index(drop=True)
           
           .rename(columns={'time': 'timestamp'})
           
          )
    
    
    
    dev["ST"] = dev["type"].map(lambda x: "Pre_ST" if "124" in x else "Post_ST")
 

    tmp = pd.merge(dev, cal_time, how='inner', on='timestamp')
    
#     ## Extracting date informationn from stamps
    
    tmp['Date_(local)'] = (tmp['timestamp']
                   
              .apply(lambda x: datetime.fromtimestamp(int(x))      
              .strftime('%d-%b-%Y'))
              .astype('str')
             )
    
    tmp['time_s'] = (tmp['timestamp']
                   
              .apply(lambda x: datetime.fromtimestamp(int(x))      
              .strftime("%H:%M:%S"))
              .astype('str')
                    )
    
    ## Path of Summary file
    
    spath = [os.path.join(p, s) for s in os.listdir(p) if "Summary" in s and s.endswith(".csv")][0]
    
    
    summary = pd.read_csv(spath)
    
    
    ## Merging data with summary file


    prf = (pd.merge(summary, tmp, how='inner', on='Date_(local)')
           .drop_duplicates(subset=['timestamp'])

          )
    
    
    
    
    

                
prf
# Out:
#     Device_SN  Preset_(mA)  Center_Frequency_(Hz)  Day  Session_#  \
# 0     170403H         3.25                  6.445    1          1
# 1     170403H         3.25                  6.445    1          1
# 2     170403H         3.25                  6.445    1          1
# 3     170403H         3.25                  6.445    1          1
# 4     170403H         3.25                  6.445    2          1
# ..        ...          ...                    ...  ...        ...
# 841   170403H         3.25                  6.445   31          1
# 842   170403H         3.25                  6.445   31          1
# 843   170403H         3.25                  6.445   31          1
# 844   170403H         3.25                  6.445   31          1
# 845   170403H         3.25                  6.445   31          1
#
#     Date_(local)  PGI-S_Pre  PGI-S_Post Stim_Start_Time_(local)  \
# 0    26-Jul-2017          4           2                09:57:31
# 1    26-Jul-2017          4           2                09:57:31
# 2    26-Jul-2017          4           2                09:57:31
# 3    26-Jul-2017          4           2                09:57:31
# 4    27-Jul-2017          5          98                09:12:39
# ..           ...        ...         ...                     ...
# 841  25-Aug-2017          4           3                08:25:26
# 842  25-Aug-2017          4           3                08:25:26
# 843  25-Aug-2017          4           3                08:25:26
# 844  25-Aug-2017          4           3                08:25:26
# 845  25-Aug-2017          4           3                08:25:26
#
#     End_Session_Time_(local)  ...  Final_Amplitude_(mA) FW_Version_Number  \
# 0                   10:37:31  ...                 95.00  2.2.Type_Product
# 1                   10:37:31  ...                 95.00  2.2.Type_Product
# 2                   10:37:31  ...                 95.00  2.2.Type_Product
# 3                   10:37:31  ...                 95.00  2.2.Type_Product
# 4                   09:14:39  ...                  3.75  2.2.Type_Product
# ..                       ...  ...                   ...               ...
# 841                 09:05:26  ...                 95.00  2.2.Type_Product
# 842                 09:05:26  ...                 95.00  2.2.Type_Product
# 843                 09:05:26  ...                 95.00  2.2.Type_Product
# 844                 09:05:26  ...                 95.00  2.2.Type_Product
# 845                 09:05:26  ...                 95.00  2.2.Type_Product
#
#      Config_Version_Number Graphics_Version_Number   timestamp type data  \
# 0         2.0.Type_Product        2.1.Type_Product  1501084394  124  393
# 1         2.0.Type_Product        2.1.Type_Product  1501084547  124  269
# 2         2.0.Type_Product        2.1.Type_Product  1501084502  125  322
# 3         2.0.Type_Product        2.1.Type_Product  1501087223  125  238
# 4         2.0.Type_Product        2.1.Type_Product  1501189044  124  401
# ..                     ...                     ...         ...  ...  ...
# 841       2.0.Type_Product        2.1.Type_Product  1503671072  124  275
# 842       2.0.Type_Product        2.1.Type_Product  1503683318  124  269
# 843       2.0.Type_Product        2.1.Type_Product  1503673549  125  248
# 844       2.0.Type_Product        2.1.Type_Product  1503686003  125  316
# 845       2.0.Type_Product        2.1.Type_Product  1503699075  125  222
#
#           ST                                           filename    time_s
# 0     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  10:53:14
# 1     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  10:55:47
# 2    Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  10:55:02
# 3    Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  11:40:23
# 4     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  15:57:24
# ..       ...                                                ...       ...
# 841   Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  09:24:32
# 842   Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  12:48:38
# 843  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  10:05:49
# 844  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  13:33:23
# 845  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  17:11:15
#
# [210 rows x 22 columns]

# %%
def get_matched_calfiles(patients_data, devpath):
       
    lst=[]

    fpath=[]

    for f in os.listdir(patients_data):
    
        if f.startswith("cal_") and f.endswith(".csv"):

            calpath = os.path.join(patients_data, f)

            with open(calpath, 'r', newline='') as csv_file:

                reader = csv.reader(line.replace('  ', ',') for line in csv_file)

                my_list = list(reader)

                fpath.append(calpath)

                lst.append(my_list[5][0])


    cal_time = pd.DataFrame(zip(lst, fpath), columns=['timestamp', 'filename'])
    

 ## Processing dev files to get timestamps to match get pre-ST and post-ST cal files

    dev = pd.read_csv(devpath)

    row = (dev.iloc[:, 0] == 'time').idxmax()

    dev.columns = dev.loc[row]

    dev = (dev.loc[row+1:, :]
           
           .reset_index(drop=True)
          )


    data_dype = ['124', '125']

    dev = (dev[dev['type']
               
               .isin(data_dype)]
           
           .sort_values(by=['type'])
           
           .reset_index(drop=True)
           
           .rename(columns={'time': 'timestamp'})
           
          )
    
    
    
    dev["ST"] = dev["type"].map(lambda x: "Pre_ST" if "124" in x else "Post_ST")
 

    tmp = pd.merge(dev, cal_time, how='inner', on='timestamp')
    
    ## Extracting date informationn from stamps
    
    tmp['Date_(local)'] = (tmp['timestamp']
                   
              .apply(lambda x: datetime.fromtimestamp(int(x))      
              .strftime('%d-%b-%Y'))
              .astype('str')
             )
    
    tmp['time_s'] = (tmp['timestamp']
                   
              .apply(lambda x: datetime.fromtimestamp(int(x))      
              .strftime("%H:%M:%S"))
              .astype('str')
                    )
    
    return tmp


    
df = get_matched_calfiles(patients_data, devpath)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-31-4d1d18d5e0d8> in <module>
#      80
#      81
# ---> 82 df = get_matched_calfiles(patients_data, devpath)
#      83
#
# <ipython-input-31-4d1d18d5e0d8> in get_matched_calfiles(patients_data, devpath)
#       5     fpath=[]
#       6
# ----> 7     for f in os.listdir(patients_data):
#       8
#       9         if f.startswith("cal_") and f.endswith(".csv"):
#
# TypeError: listdir: path should be string, bytes, os.PathLike, integer or None, not list

# %%
summary = pd.read_csv(spath)


tmp = (pd.merge(summary, df, how='inner', on='Date_(local)')
       .drop_duplicates(subset=['timestamp'])
       
      )

tmp.to_csv("/Users/habbasi/Desktop/summary.csv")
tmp
# Out:
#     Device_SN  Preset_(mA)  Center_Frequency_(Hz)  Day  Session_#  \
# 0     170614H         2.75                  6.054    1          1
# 1     170614H         2.75                  6.054    1          1
# 2     170614H         2.75                  6.054    1          1
# 3     170614H         2.75                  6.054    1          1
# 8     170614H         2.75                  6.054    2          1
# ..        ...          ...                    ...  ...        ...
# 352   170614H         2.75                  6.054   36          1
# 353   170614H         2.75                  6.054   36          1
# 354   170614H         2.75                  6.054   36          1
# 359   170614H         2.75                  6.054   37          1
# 360   170614H         2.75                  6.054   37          1
#
#     Date_(local)  PGI-S_Pre  PGI-S_Post Stim_Start_Time_(local)  \
# 0    06-Oct-2017          6           2                09:50:05
# 1    06-Oct-2017          6           2                09:50:05
# 2    06-Oct-2017          6           2                09:50:05
# 3    06-Oct-2017          6           2                09:50:05
# 8    07-Oct-2017          6           3                07:34:44
# ..           ...        ...         ...                     ...
# 352  10-Nov-2017          4           1                12:10:36
# 353  10-Nov-2017          4           1                12:10:36
# 354  10-Nov-2017          4           1                12:10:36
# 359  11-Nov-2017          5           2                11:17:58
# 360  11-Nov-2017          5           2                11:17:58
#
#     End_Session_Time_(local)  ...  Final_Amplitude_(mA) FW_Version_Number  \
# 0                   10:30:05  ...                    95  2.2.Type_Product
# 1                   10:30:05  ...                    95  2.2.Type_Product
# 2                   10:30:05  ...                    95  2.2.Type_Product
# 3                   10:30:05  ...                    95  2.2.Type_Product
# 8                   08:14:44  ...                    95  2.2.Type_Product
# ..                       ...  ...                   ...               ...
# 352                 12:50:36  ...                    95  2.2.Type_Product
# 353                 12:50:36  ...                    95  2.2.Type_Product
# 354                 12:50:36  ...                    95  2.2.Type_Product
# 359                 11:57:58  ...                    95  2.2.Type_Product
# 360                 11:57:58  ...                    95  2.2.Type_Product
#
#      Config_Version_Number Graphics_Version_Number   timestamp type  data  \
# 0         2.0.Type_Product        2.1.Type_Product  1507304910  124  2480
# 1         2.0.Type_Product        2.1.Type_Product  1507328813  124  2284
# 2         2.0.Type_Product        2.1.Type_Product  1507331306  125   238
# 3         2.0.Type_Product        2.1.Type_Product  1507308759  125   243
# 8         2.0.Type_Product        2.1.Type_Product  1507430501  124  1384
# ..                     ...                     ...         ...  ...   ...
# 352       2.0.Type_Product        2.1.Type_Product  1510337399  124   442
# 353       2.0.Type_Product        2.1.Type_Product  1510365034  125   226
# 354       2.0.Type_Product        2.1.Type_Product  1510339861  125   249
# 359       2.0.Type_Product        2.1.Type_Product  1510420639  124  1695
# 360       2.0.Type_Product        2.1.Type_Product  1510423101  125   220
#
#           ST                                           filename    time_s
# 0     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  10:48:30
# 1     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  17:26:53
# 2    Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  18:08:26
# 3    Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  11:52:39
# 8     Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  21:41:41
# ..       ...                                                ...       ...
# 352   Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  12:09:59
# 353  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  19:50:34
# 354  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  12:51:01
# 359   Pre_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  11:17:19
# 360  Post_ST  /Users/habbasi/Desktop/Interview_Data Analysis...  11:58:21
#
# [159 rows x 22 columns]

# %%
def data_extraction(tmp):
    
    ## list of paths of cal files used for PRE-ST and Post-ST
    
    cal_flist = list(tmp['filename'])


    fft_data = []
    
    gryo_data = []
    
    acc_data = []

    for i, cal in enumerate(cal_flist):


        match1=['freq', 'fft']
        match2= ['time', 'gyroX', 'gyroY', 'gyroZ']
        match3= ['time', 'accelX', 'accelY', 'accelZ']


        with open(cal) as csvfile:

            call_data = list(csv.reader(csvfile))
            
            # Getting index if it matches with string list 

            index1 = [index for index, f in enumerate(call_data) if f == match1][0]

            index2 = [index for index, f in enumerate(call_data) if f == match2][0]

            index3 = [index for index, f in enumerate(call_data) if f == match3][0]

            timestamp = call_data[5][0]


        fft = pd.DataFrame(call_data[index1+1:index2], columns=match1)       

        gyro = pd.DataFrame(call_data[index2+1:index3], columns=match2)

        acc = pd.DataFrame(call_data[index3+1:], columns=match3) 

        fft['timestamp'] = call_data[5][0]
        gyro['timestamp'] = call_data[5][0]
        acc['timestamp'] = call_data[5][0]

        fft_data.append(fft)
        gryo_data.append(gyro)
        acc_data.append(acc)


    fft = (pd.concat(fft_data)
           .merge(tmp,
                    how='inner', on='timestamp')
          )
        
        
    gryo = (pd.concat(gryo_data)
            .merge(tmp,
                    how='inner', on='timestamp')
           )
    
    acc = (pd.concat(acc_data)
           .merge(tmp,
                    how='inner', on='timestamp')
          )
    
    
    return fft, gryo, acc


fft = data_extraction(tmp)[0]
    
gryo = data_extraction(tmp)[1] 

acc = data_extraction(tmp)[2]

# %%
def PSD_plotting(fft):
    

    pf=fft.copy()
    
    ## converting columns to floats

    pf[['freq', 'fft']] = (pf[['freq', 'fft']]
              .astype('float')
              .round(2)

             )
    
    
    ## Filtering data which are between 4.0 to 12.03 HZ

    pf = (pf.query('freq >= 4.0 & freq <=12.03')
          
          .reset_index(drop=True)
          
         )
    
    # Calculation PSD from fft values by applying formula
    
    
    # Total no of Samples

    N=pf.shape[0]


    pf['PSD'] = (pf['fft']
                 
                 .apply(lambda x: (1/(2*3.14*N)) * abs(x)** 2)
                 
                )

    # Aggregation of rows grouped by frequency and stimulus session

    tp = (pf.groupby(['freq', 'type', 'ST'])
          
          .agg({'PSD': ['mean','median']})
          
          .reset_index()
          
         )
    
    tp.columns = ['freq', 'type', 'ST','mean','median']
    
    

    # Peak PSD value for each of Pre-ST and Post-ST session

    pre_ST_idx = tp.query("type == '124'")['mean'].idxmax()

    post_ST_idx = tp.query("type == '125'")['mean'].idxmax()

    preST_peak = tp['freq'][pre_ST_idx]

    postST_peak = tp['freq'][post_ST_idx]

    # Plotting

    g = (ggplot(tp, aes(x='freq', y='mean', color='ST')) 
         + geom_line()
         + theme_bw() 
         + theme(figure_size=(8, 6))
         + geom_vline(xintercept=[preST_peak, postST_peak],
                     colour=['#3690c0', '#ef3b2c'],
                     size=[0.8, 1],
                     linetype="dotted")
         + annotate("text", label = "Pre-ST:  " + str(preST_peak) + 'HZ', color="#3690c0", size = 12, x = 5, y = 30)
         + annotate("text", label = "Post-ST:  " + str(postST_peak) + 'HZ', color="#ef3b2c", size = 12, x = 9, y = 30)
         + labs(x='Frequency (Hz)', y='Power Spectral Density (DBM/Hz)')
         + ggtitle("Patient Hand Tremor data") 
         + scale_colour_manual(names=['Pre-S', 'Post-ST'],
                              values=["#ef3b2c","#3690c0"])
         + guides(color=guide_legend(title="Stimulus Session"))

        )

    return g
# Out:
# /Users/habbasi/plotnine/plotnine/scales/scale.py:91: PlotnineWarning: scale_color_manual could not recognise parameter `names`
# <ggplot: (7051784729)>
